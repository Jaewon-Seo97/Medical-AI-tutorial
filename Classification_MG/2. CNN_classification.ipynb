# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,ReduceLROnPlateau
# Out:
# 2023-10-04 07:52:53.399819: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-04 07:52:53.625909: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-04 07:52:54.684127: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /root/miniconda3/envs/tf/lib/python3.9/site-packages/cv2/../../lib64::/root/miniconda3/envs/tf/lib/:/root/miniconda3/lib/:/root/miniconda3/envs/tf/lib/:/root/miniconda3/lib/:/root/miniconda3/envs/tf/lib/:/root/miniconda3/lib/
# 2023-10-04 07:52:54.684268: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /root/miniconda3/envs/tf/lib/python3.9/site-packages/cv2/../../lib64::/root/miniconda3/envs/tf/lib/:/root/miniconda3/lib/:/root/miniconda3/envs/tf/lib/:/root/miniconda3/lib/:/root/miniconda3/envs/tf/lib/:/root/miniconda3/lib/
# 2023-10-04 07:52:54.684275: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Getting numpy data
train_x = np.load(os.path.join(os.path.abspath('.'), 'npy', 'train_img.npy'))
test_x = np.load(os.path.join(os.path.abspath('.'), 'npy', 'test_img.npy'))
train_y = np.load(os.path.join(os.path.abspath('.'), 'npy', 'train_lab.npy'))
test_y = np.load(os.path.join(os.path.abspath('.'), 'npy', 'test_lab.npy'))

print('Data shape')
print(f'Train img: {train_x.shape} | Train lab: {train_y.shape}')
print(f'Test img: {test_x.shape} | Test lab: {test_y.shape}')
# Out:
# Data shape
# Train img: (450, 512, 512, 1) | Train lab: (450, 2)
# Test img: (50, 512, 512, 1) | Test lab: (50, 2)

# %%
def Simple_CNNmodel(input_img, base = 32, scale = 2, n_layers = 6):

    x = input_img

    for n in range(n_layers):
        x = Conv2D(((scale)**n)*base, 3, activation=None, padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)
        x = Activation(activation='relu')(x)
        x = Conv2D(((scale)**n)*base, 3, activation=None, padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)
        x = Activation(activation='relu')(x)
        if n != n_layers:
            x = MaxPooling2D(pool_size=(2, 2))(x)
        else:
            pass
    
    out = GlobalAveragePooling2D(name="avg_pool")(x)
    out = Dense(128, activation="relu")(out)
    out = BatchNormalization()(out)
    
    out = Dense(64, activation="relu")(out)
    out = BatchNormalization()(out)
    out = Dropout(0.3)(out)
    
    out = Dense(n_class, activation="softmax")(out)
    model = Model(inputs=input_img, outputs=out)
    
    return model

# %%
# Training classification model using Simple CNN model

path_save = os.path.join(os.path.abspath('.'), 'Result', 'model_simple')
os.makedirs(path_save, exist_ok=True)

## parameter setting
n_class = 2         
imageSize = 512     
lr = 0.0001
epochs = 50
batch = 10
loss_function = "categorical_crossentropy"

## model build
input_img = Input(shape=(imageSize,imageSize,1))

model = Simple_CNNmodel(input_img, n_class)
model.summary()         # Check model structure

## model compile
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
model.compile(
        optimizer=optimizer, loss=loss_function, metrics=["accuracy"]
    )
# Out:
# 2023-10-04 08:02:39.924316: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-04 08:02:40.814186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7924 MB memory:  -> device: 0, name: NVIDIA A100 80GB PCIe MIG 1g.10gb, pci bus id: 0000:ca:00.0, compute capability: 8.0
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 512, 512, 1)]     0
#
#  conv2d (Conv2D)             (None, 512, 512, 2)       20
#
#  batch_normalization (BatchN  (None, 512, 512, 2)      8
#  ormalization)
#
#  activation (Activation)     (None, 512, 512, 2)       0
#
#  conv2d_1 (Conv2D)           (None, 512, 512, 2)       38
#
#  batch_normalization_1 (Batc  (None, 512, 512, 2)      8
#  hNormalization)
#
#  activation_1 (Activation)   (None, 512, 512, 2)       0
#
#  max_pooling2d (MaxPooling2D  (None, 256, 256, 2)      0
#  )
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 4)       76
#
#  batch_normalization_2 (Batc  (None, 256, 256, 4)      16
#  hNormalization)
#
#  activation_2 (Activation)   (None, 256, 256, 4)       0
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 4)       148
#
#  batch_normalization_3 (Batc  (None, 256, 256, 4)      16
#  hNormalization)
#
#  activation_3 (Activation)   (None, 256, 256, 4)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 128, 128, 4)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 8)       296
#
#  batch_normalization_4 (Batc  (None, 128, 128, 8)      32
#  hNormalization)
#
#  activation_4 (Activation)   (None, 128, 128, 8)       0
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 8)       584
#
#  batch_normalization_5 (Batc  (None, 128, 128, 8)      32
#  hNormalization)
#
#  activation_5 (Activation)   (None, 128, 128, 8)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 64, 64, 8)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 16)        1168
#
#  batch_normalization_6 (Batc  (None, 64, 64, 16)       64
#  hNormalization)
#
#  activation_6 (Activation)   (None, 64, 64, 16)        0
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 16)        2320
#
#  batch_normalization_7 (Batc  (None, 64, 64, 16)       64
#  hNormalization)
#
#  activation_7 (Activation)   (None, 64, 64, 16)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 16)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        4640
#
#  batch_normalization_8 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_9 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  avg_pool (GlobalAveragePool  (None, 64)               0
#  ing2D)
#
#  dense (Dense)               (None, 128)               8320
#
#  batch_normalization_12 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_13 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 92,444
# Trainable params: 91,556
# Non-trainable params: 888
# _________________________________________________________________

# %%
## Callback
checkpointer = ModelCheckpoint(filepath=os.path.join(path_save,f'best_model.h5'), 
                                verbose=1, 
                                save_weights_only=True, 
                                save_best_only=True, 
                                monitor='val_loss', 
                                save_freq='epoch')

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0, min_delta=0.001, verbose=1)
callbacks_list = [reduce_lr, checkpointer]


## training model
model.fit(train_x, train_y,
            steps_per_epoch=len(train_x) // batch, epochs=epochs,
            validation_split=0.2,
            callbacks=callbacks_list,
            shuffle=True
                        )

## saving last model weight
model.save_weights(os.path.join(path_save,f'last_model.h5'))
# Out:
# Epoch 1/50
# 2023-10-04 08:02:59.714692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8100
# 2023-10-04 08:03:02.459723: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-04 08:03:03.048181: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fa168beeb10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-04 08:03:03.048217: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA A100 80GB PCIe MIG 1g.10gb, Compute Capability 8.0
# 2023-10-04 08:03:03.059487: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-04 08:03:03.300319: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 45/45 [==============================] - ETA: 0s - loss: 1.0398 - accuracy: 0.5556
# Epoch 1: val_loss improved from inf to 0.70269, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 25s 134ms/step - loss: 1.0398 - accuracy: 0.5556 - val_loss: 0.7027 - val_accuracy: 0.4556 - lr: 1.0000e-04
# Epoch 2/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.7726 - accuracy: 0.6307
# Epoch 2: val_loss improved from 0.70269 to 0.69991, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 3s 56ms/step - loss: 0.7646 - accuracy: 0.6361 - val_loss: 0.6999 - val_accuracy: 0.4556 - lr: 1.0000e-04
# Epoch 3/50
# 45/45 [==============================] - ETA: 0s - loss: 0.7288 - accuracy: 0.6639
# Epoch 3: val_loss improved from 0.69991 to 0.69972, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 3s 56ms/step - loss: 0.7288 - accuracy: 0.6639 - val_loss: 0.6997 - val_accuracy: 0.4556 - lr: 1.0000e-04
# Epoch 4/50
# 45/45 [==============================] - ETA: 0s - loss: 0.6105 - accuracy: 0.7194
# Epoch 4: val_loss did not improve from 0.69972
# 45/45 [==============================] - 3s 63ms/step - loss: 0.6105 - accuracy: 0.7194 - val_loss: 0.7002 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 5/50
# 45/45 [==============================] - ETA: 0s - loss: 0.5082 - accuracy: 0.7694
# Epoch 5: val_loss did not improve from 0.69972
# 45/45 [==============================] - 2s 53ms/step - loss: 0.5082 - accuracy: 0.7694 - val_loss: 0.7098 - val_accuracy: 0.5556 - lr: 1.0000e-04
# Epoch 6/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.7642
# Epoch 6: val_loss did not improve from 0.69972
# 45/45 [==============================] - 3s 59ms/step - loss: 0.5464 - accuracy: 0.7611 - val_loss: 0.7535 - val_accuracy: 0.5444 - lr: 1.0000e-04
# Epoch 7/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.7972
# Epoch 7: val_loss did not improve from 0.69972
# 45/45 [==============================] - 2s 53ms/step - loss: 0.4793 - accuracy: 0.7972 - val_loss: 0.8938 - val_accuracy: 0.5444 - lr: 1.0000e-04
# Epoch 8/50
# 45/45 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8417
# Epoch 8: val_loss did not improve from 0.69972
# 45/45 [==============================] - 3s 57ms/step - loss: 0.3897 - accuracy: 0.8417 - val_loss: 0.8022 - val_accuracy: 0.5889 - lr: 1.0000e-04
# Epoch 9/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4548 - accuracy: 0.8167
# Epoch 9: val_loss did not improve from 0.69972
# 45/45 [==============================] - 3s 57ms/step - loss: 0.4548 - accuracy: 0.8167 - val_loss: 0.8578 - val_accuracy: 0.6000 - lr: 1.0000e-04
# Epoch 10/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4414 - accuracy: 0.8222
# Epoch 10: val_loss did not improve from 0.69972
# 45/45 [==============================] - 2s 52ms/step - loss: 0.4414 - accuracy: 0.8222 - val_loss: 0.7820 - val_accuracy: 0.6111 - lr: 1.0000e-04
# Epoch 11/50
# 45/45 [==============================] - ETA: 0s - loss: 0.4267 - accuracy: 0.8111
# Epoch 11: val_loss improved from 0.69972 to 0.57715, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 2s 54ms/step - loss: 0.4267 - accuracy: 0.8111 - val_loss: 0.5772 - val_accuracy: 0.7444 - lr: 1.0000e-04
# Epoch 12/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.8580
# Epoch 12: val_loss improved from 0.57715 to 0.50331, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 3s 59ms/step - loss: 0.2880 - accuracy: 0.8611 - val_loss: 0.5033 - val_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 13/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.3019 - accuracy: 0.8778
# Epoch 13: val_loss improved from 0.50331 to 0.36278, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 2s 54ms/step - loss: 0.3124 - accuracy: 0.8722 - val_loss: 0.3628 - val_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 14/50
# 45/45 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.8778
# Epoch 14: val_loss improved from 0.36278 to 0.34966, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 3s 57ms/step - loss: 0.2913 - accuracy: 0.8778 - val_loss: 0.3497 - val_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 15/50
# 45/45 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9111
# Epoch 15: val_loss did not improve from 0.34966
# 45/45 [==============================] - 2s 54ms/step - loss: 0.2204 - accuracy: 0.9111 - val_loss: 0.3823 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 16/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1761 - accuracy: 0.9403
# Epoch 16: val_loss did not improve from 0.34966
# 45/45 [==============================] - 2s 53ms/step - loss: 0.1777 - accuracy: 0.9389 - val_loss: 0.3772 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 17/50
# 45/45 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.8972
# Epoch 17: val_loss did not improve from 0.34966
# 45/45 [==============================] - 2s 52ms/step - loss: 0.2745 - accuracy: 0.8972 - val_loss: 0.3798 - val_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 18/50
# 45/45 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9028
# Epoch 18: val_loss did not improve from 0.34966
# 45/45 [==============================] - 2s 54ms/step - loss: 0.2161 - accuracy: 0.9028 - val_loss: 0.4731 - val_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 19/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.2049 - accuracy: 0.9233
# Epoch 19: val_loss did not improve from 0.34966
# 45/45 [==============================] - 3s 56ms/step - loss: 0.2016 - accuracy: 0.9250 - val_loss: 0.5276 - val_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 20/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9176
# Epoch 20: val_loss did not improve from 0.34966
# 45/45 [==============================] - 2s 52ms/step - loss: 0.2058 - accuracy: 0.9194 - val_loss: 0.5101 - val_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 21/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.9290
# Epoch 21: val_loss did not improve from 0.34966
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1662 - accuracy: 0.9306 - val_loss: 0.3691 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 22/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.2039 - accuracy: 0.9148
# Epoch 22: val_loss improved from 0.34966 to 0.28832, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 2s 54ms/step - loss: 0.2151 - accuracy: 0.9111 - val_loss: 0.2883 - val_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 23/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.2271 - accuracy: 0.8977
# Epoch 23: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.2264 - accuracy: 0.8972 - val_loss: 0.6730 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 24/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1919 - accuracy: 0.9290
# Epoch 24: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 56ms/step - loss: 0.1992 - accuracy: 0.9250 - val_loss: 0.3204 - val_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 25/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1429 - accuracy: 0.9517
# Epoch 25: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1420 - accuracy: 0.9500 - val_loss: 0.3839 - val_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 26/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1248 - accuracy: 0.9556
# Epoch 26: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 54ms/step - loss: 0.1248 - accuracy: 0.9556 - val_loss: 0.3298 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 27/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1369 - accuracy: 0.9403
# Epoch 27: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 52ms/step - loss: 0.1346 - accuracy: 0.9417 - val_loss: 0.5408 - val_accuracy: 0.7889 - lr: 1.0000e-04
# Epoch 28/50
# 45/45 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9667
# Epoch 28: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.0997 - accuracy: 0.9667 - val_loss: 0.3285 - val_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 29/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1598 - accuracy: 0.9347
# Epoch 29: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1566 - accuracy: 0.9361 - val_loss: 0.3681 - val_accuracy: 0.8333 - lr: 1.0000e-04
# Epoch 30/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1903 - accuracy: 0.9167
# Epoch 30: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1903 - accuracy: 0.9167 - val_loss: 0.6586 - val_accuracy: 0.8111 - lr: 1.0000e-04
# Epoch 31/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9417
# Epoch 31: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1409 - accuracy: 0.9417 - val_loss: 0.2901 - val_accuracy: 0.8556 - lr: 1.0000e-04
# Epoch 32/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9361
# Epoch 32: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 32: val_loss did not improve from 0.28832
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1573 - accuracy: 0.9361 - val_loss: 0.6303 - val_accuracy: 0.7889 - lr: 1.0000e-04
# Epoch 33/50
# 45/45 [==============================] - ETA: 0s - loss: 0.0874 - accuracy: 0.9667
# Epoch 33: val_loss improved from 0.28832 to 0.25459, saving model to /home/user/workdir/my_data/Result/model_simple/best_model.h5
# 45/45 [==============================] - 3s 56ms/step - loss: 0.0874 - accuracy: 0.9667 - val_loss: 0.2546 - val_accuracy: 0.8333 - lr: 1.0000e-05
# Epoch 34/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9659
# Epoch 34: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 54ms/step - loss: 0.0845 - accuracy: 0.9667 - val_loss: 0.2589 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 35/50
# 45/45 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9639
# Epoch 35: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 50ms/step - loss: 0.0981 - accuracy: 0.9639 - val_loss: 0.2955 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 36/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9444
# Epoch 36: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 52ms/step - loss: 0.1469 - accuracy: 0.9444 - val_loss: 0.2715 - val_accuracy: 0.8778 - lr: 1.0000e-05
# Epoch 37/50
# 45/45 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9639
# Epoch 37: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 51ms/step - loss: 0.0898 - accuracy: 0.9639 - val_loss: 0.2760 - val_accuracy: 0.8667 - lr: 1.0000e-05
# Epoch 38/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9886
# Epoch 38: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 51ms/step - loss: 0.0487 - accuracy: 0.9889 - val_loss: 0.2703 - val_accuracy: 0.8889 - lr: 1.0000e-05
# Epoch 39/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0670 - accuracy: 0.9830
# Epoch 39: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 50ms/step - loss: 0.0673 - accuracy: 0.9833 - val_loss: 0.2618 - val_accuracy: 0.8444 - lr: 1.0000e-05
# Epoch 40/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9361
# Epoch 40: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1230 - accuracy: 0.9361 - val_loss: 0.2680 - val_accuracy: 0.8778 - lr: 1.0000e-05
# Epoch 41/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1115 - accuracy: 0.9500
# Epoch 41: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 53ms/step - loss: 0.1115 - accuracy: 0.9500 - val_loss: 0.2699 - val_accuracy: 0.8778 - lr: 1.0000e-05
# Epoch 42/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0791 - accuracy: 0.9688
# Epoch 42: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 53ms/step - loss: 0.0782 - accuracy: 0.9694 - val_loss: 0.2703 - val_accuracy: 0.8556 - lr: 1.0000e-05
# Epoch 43/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1048 - accuracy: 0.9602
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 43: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 53ms/step - loss: 0.1030 - accuracy: 0.9611 - val_loss: 0.2738 - val_accuracy: 0.8556 - lr: 1.0000e-05
# Epoch 44/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1097 - accuracy: 0.9631
# Epoch 44: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 51ms/step - loss: 0.1076 - accuracy: 0.9639 - val_loss: 0.2761 - val_accuracy: 0.8667 - lr: 1.0000e-06
# Epoch 45/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9545
# Epoch 45: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 52ms/step - loss: 0.1290 - accuracy: 0.9556 - val_loss: 0.2785 - val_accuracy: 0.8778 - lr: 1.0000e-06
# Epoch 46/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9716
# Epoch 46: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 51ms/step - loss: 0.0759 - accuracy: 0.9722 - val_loss: 0.2752 - val_accuracy: 0.8889 - lr: 1.0000e-06
# Epoch 47/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0932 - accuracy: 0.9631
# Epoch 47: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 54ms/step - loss: 0.0924 - accuracy: 0.9639 - val_loss: 0.2781 - val_accuracy: 0.8778 - lr: 1.0000e-06
# Epoch 48/50
# 45/45 [==============================] - ETA: 0s - loss: 0.1075 - accuracy: 0.9611
# Epoch 48: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 52ms/step - loss: 0.1075 - accuracy: 0.9611 - val_loss: 0.2771 - val_accuracy: 0.8778 - lr: 1.0000e-06
# Epoch 49/50
# 44/45 [============================>.] - ETA: 0s - loss: 0.0683 - accuracy: 0.9830
# Epoch 49: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 52ms/step - loss: 0.0684 - accuracy: 0.9833 - val_loss: 0.2770 - val_accuracy: 0.8778 - lr: 1.0000e-06
# Epoch 50/50
# 45/45 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9833
# Epoch 50: val_loss did not improve from 0.25459
# 45/45 [==============================] - 2s 51ms/step - loss: 0.0575 - accuracy: 0.9833 - val_loss: 0.2791 - val_accuracy: 0.8889 - lr: 1.0000e-06

# %%
# Evaluation using test data
_loss, _acc = model.evaluate(train_x, train_y, batch_size=10, verbose=1)
print('Last model accuracy')
print(f'loss: {_loss:0.3f} | accuracy: {_acc:0.3f}')
_loss, _acc = model.evaluate(test_x, test_y, batch_size=10, verbose=1)
print('Last model accuracy')
print(f'loss: {_loss:0.3f} | accuracy: {_acc:0.3f}')
# Out:
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0600 - accuracy: 0.9667
# Last model accuracy
# loss: 0.060 | accuracy: 0.967
# 5/5 [==============================] - 0s 21ms/step - loss: 0.7497 - accuracy: 0.7800
# Last model accuracy
# loss: 0.750 | accuracy: 0.780

# %%
## Using best model
model.load_weights(os.path.join(path_save,f'best_model.h5'))
_loss, _acc = model.evaluate(test_x, test_y, batch_size=10, verbose=1)
print('Best model accuracy')
print(f'loss: {_loss:0.3f} | accuracy: {_acc:0.3f}')
# Out:
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7497 - accuracy: 0.7800
# Best model accuracy
# loss: 0.750 | accuracy: 0.780

# %%
print(test_result.shape)
# Out:
# (50, 2)

# %%
# Checking fail data
test_result = model.predict(test_x, batch_size=10)

for a in range(len(test_result)):
    if test_result[a].argmax()!=test_y[a].argmax():
        plt.title(f'GT: {test_y[a].argmax()} | Result: {test_result[a].argmax()}')
        plt.imshow(test_x[a], cmap='gray')
        plt.show()
# Out:
# 5/5 [==============================] - 0s 16ms/step

# %%
def drawing_ROCcurve(test_y, test_result, path_save):
    from sklearn.metrics import roc_curve, auc
    n_classes = test_y.shape[-1]
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(test_y[:, i], test_result[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(test_y.ravel(), test_result.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    
    
    # First aggregate all false positive rates
    lw = 2
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # Then interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    # Finally average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # Plot all ROC curves
    plt.figure(figsize=(10,10))
    plt.plot(
        fpr["micro"],
        tpr["micro"],
        label="micro-average (auc = {0:0.2f})".format(roc_auc["micro"]),
        color="maroon",
        linestyle=":",
        linewidth=4,
    )

    plt.plot(
        fpr["macro"],
        tpr["macro"],
        label="macro-average (auc = {0:0.2f})".format(roc_auc["macro"]),
        color="navy",
        linestyle=":",
        linewidth=4,
    )

    
    for i, color in zip(range(n_classes), ['blue', 'yellow']):
        plt.plot(
            fpr[i],
            tpr[i],
            lw=lw,
            label="ROC curve (auc = {1:0.2f})".format(i, roc_auc[i]),
        )

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.xlabel("False Positive Rate", fontsize=20)
    plt.ylabel("True Positive Rate", fontsize=20)
    plt.title("Receiver operating characteristic curves", fontsize=20)
    plt.legend(loc="lower right", fontsize=14)
    plt.savefig(f'{path_save}/ROC_curve.png')

# %%
drawing_ROCcurve(test_y, model.predict(test_result), path_save)
